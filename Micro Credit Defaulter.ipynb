# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv("D:\Internship project\Micro Credit Project\Data file.csv")

# %%
data
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %%
data.drop(columns=['Unnamed: 0'],axis=1, inplace=True)

# %%
data.shape
# Out:
# (209593, 36)

# %%
data.describe()
# Out:
#                label            aon   daily_decr30   daily_decr90  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean        0.875177    8112.343445    5381.402289    6082.515068
# std         0.330519   75696.082531    9220.623400   10918.812767
# min         0.000000     -48.000000     -93.012667     -93.012667
# 25%         1.000000     246.000000      42.440000      42.692000
# 50%         1.000000     527.000000    1469.175667    1500.000000
# 75%         1.000000     982.000000    7244.000000    7802.790000
# max         1.000000  999860.755168  265926.000000  320630.000000
#
#             rental30       rental90  last_rech_date_ma  last_rech_date_da  \
# count  209593.000000  209593.000000      209593.000000      209593.000000
# mean     2692.581910    3483.406534        3755.847800        3712.202921
# std      4308.586781    5770.461279       53905.892230       53374.833430
# min    -23737.140000  -24720.580000         -29.000000         -29.000000
# ...

# %%
data['label'].value_counts()
# Out:
# 1    183431
# 0     26162
# Name: label, dtype: int64

# %%
data.isna().sum()
# Out:
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# pcircle                 0
# ...

# %%
data.drop_duplicates()
data
# Out:
#         label       msisdn     aon  daily_decr30  daily_decr90  rental30  \
# 0           0  21408I70789   272.0   3055.050000   3065.150000    220.13
# 1           1  76462I70374   712.0  12122.000000  12124.750000   3691.26
# 2           1  17943I70372   535.0   1398.000000   1398.000000    900.13
# 3           1  55773I70781   241.0     21.228000     21.228000    159.42
# 4           1  03813I82730   947.0    150.619333    150.619333   1098.90
# ...       ...          ...     ...           ...           ...       ...
# 209588      1  22758I85348   404.0    151.872333    151.872333   1089.19
# 209589      1  95583I84455  1075.0     36.936000     36.936000   1728.36
# 209590      1  28556I85350  1013.0  11843.111667  11904.350000   5861.83
# 209591      1  59712I82733  1732.0  12488.228333  12574.370000    411.83
# 209592      1  65061I85339  1581.0   4489.362000   4534.820000    483.92
#
#         rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
    
corr_mat=data.corr().abs()
plt.figure(figsize=[120,80])
sns.heatmap(corr_mat,annot=True,annot_kws= {'size':30})
plt.title("correlation Matrix")
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 36 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   label                 209593 non-null  int64
#  1   msisdn                209593 non-null  object
#  2   aon                   209593 non-null  float64
#  3   daily_decr30          209593 non-null  float64
#  4   daily_decr90          209593 non-null  float64
#  5   rental30              209593 non-null  float64
#  6   rental90              209593 non-null  float64
#  7   last_rech_date_ma     209593 non-null  float64
#  8   last_rech_date_da     209593 non-null  float64
#  9   last_rech_amt_ma      209593 non-null  int64
#  10  cnt_ma_rech30         209593 non-null  int64
#  11  fr_ma_rech30          209593 non-null  float64
#  12  sumamnt_ma_rech30     209593 non-null  float64
#  13  medianamnt_ma_rech30  209593 non-null  float64
# ...

# %%
drop_columns=['msisdn','daily_decr30','rental90','medianamnt_ma_rech30','cnt_ma_rech90','medianamnt_loans90','payback30','pdate','sumamnt_ma_rech90']

# %%
data.drop(columns=drop_columns, axis=1,inplace=True)

# %%
plt.figure(figsize=(20,10), facecolor='blue')
plotnumber=1

for column in data:
    if plotnumber<=15 :
        ax= plt.subplot(3,5,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column,fontsize=15)
        
    plotnumber+=1
plt.show()

# %%
data
# Out:
#         label     aon  daily_decr90  rental30  last_rech_date_ma  \
# 0           0   272.0   3065.150000    220.13                2.0
# 1           1   712.0  12124.750000   3691.26               20.0
# 2           1   535.0   1398.000000    900.13                3.0
# 3           1   241.0     21.228000    159.42               41.0
# 4           1   947.0    150.619333   1098.90                4.0
# ...       ...     ...           ...       ...                ...
# 209588      1   404.0    151.872333   1089.19                1.0
# 209589      1  1075.0     36.936000   1728.36                4.0
# 209590      1  1013.0  11904.350000   5861.83                3.0
# 209591      1  1732.0  12574.370000    411.83                2.0
# 209592      1  1581.0   4534.820000    483.92               13.0
#
#         last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  \
# 0                     0.0              1539              2          21.0
# ...

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.metrics import accuracy_score, confusion_matrix,roc_curve, roc_auc_score
from sklearn.metrics import classification_report

# %%
x=data.drop(columns=['label'])
y=data['label']

# %%
scalar=StandardScaler()
x_scaled= scalar.fit_transform(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [11], in <cell line: 2>()
#       1 scalar=StandardScaler()
# ----> 2 x_scaled= scalar.fit_transform(x)
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:852, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     848 # non-optimized default implementation; override when a better
#     849 # method is possible for a given clustering algorithm
#     850 if y is None:
#     851     # fit method of arity 1 (unsupervised transformation)
# --> 852     return self.fit(X, **fit_params).transform(X)
#     853 else:
#     854     # fit method of arity 2 (supervised transformation)
#     855     return self.fit(X, y, **fit_params).transform(X)
#
# File ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:806, in StandardScaler.fit(self, X, y, sample_weight)
#     804 # Reset internal state before fitting
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
data['pcircle']=le.fit_transform(data['pcircle'])

# %%
data['pcircle'].value_counts()
# Out:
# 0    209593
# Name: pcircle, dtype: int64

# %%
scalar=StandardScaler()
x_scaled= scalar.fit_transform(x)

# %%
x_scaled.shape
# Out:
# (209593, 26)

# %%
x_train,x_test,y_train,y_test= train_test_split(x_scaled,y,test_size=0.25,random_state=2656)

# %%
LR=LogisticRegression()

# %%
LR.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=LR.predict(x_test)

# %%
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
accuracy=accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.8753220481306895

# %%
CF=confusion_matrix(y_test,y_pred)
CF
# Out:
# array([[  107,  6455],
#        [   78, 45759]], dtype=int64)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.02      0.03      6562
#            1       0.88      1.00      0.93     45837
#
#     accuracy                           0.88     52399
#    macro avg       0.73      0.51      0.48     52399
# weighted avg       0.84      0.88      0.82     52399

# %%
auc_score=roc_auc_score(y_test,y_pred)
auc_score
# Out:
# 0.5073021611098687
